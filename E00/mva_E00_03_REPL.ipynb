# %% [markdown]
# <a href="https://colab.research.google.com/github/hig3r/mva/blob/2026/L00/mva_L00_03_REPL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # mva_E00_03_REPL
#
# - 学籍番号 [ ] 氏名 [ ]
# - 学籍番号 [ ] 氏名 [ ]

# %% [markdown]
# セルを順に実行するか，いったん，ランタイム>すべてのセルを実行 します

# %%
#サードパーティライブラリ
import numpy as np #数値計算

# %% [markdown]
# Colabでは，Pythonの四則演算を，コードセルの中にいきなり書くことができます．複数の式を改行で区切って書くことができます．セル内の最後の評価結果が表示されます．

# %%
3+5 # 最後から2番目に評価される式
4+6 # 最後に評価される式

# %% [markdown]
# 巾乗(2乗，3乗など)は**です．平方根は `np.sqrt`, 三角関数，指数関数は `np.sin`, `np.exp` などです．Geminiに聞いてみましょう．数値計算ライブラリ numpy, np を使うため，表示が少し変わります．

# %%
2**3

# %%
(2+2*3)/2+np.sqrt(2)

# %% [markdown]
# 関数printに与えると，それぞれの出力が表示されます

# %%
print(3+5)
print((2+2*3)/2+np.sqrt(2))

# %% [markdown]
# 変数宣言不要で変数に代入することができます．型は不要です．代入文には返り値がないので何も表示されません．

# %%
x=3
y=2.5
z=9/7

# %% [markdown]
# 値を見たい時は下のようにします．

# %%
x=3
y=2.5
z=9/7
z

# %%
x

# %% [markdown]
# 変数を使って計算できます．

# %%
x*y+z

# %% [markdown]
# ## 実行順序の話

# %% [markdown]
# すべてのセルを実行した時には，上のセルから順に実行されます

# %% [markdown]
# この時点で代入されていない変数は値を持ちません

# %%
b # エラーになる

# %%
a

# %% [markdown]
# しかし，代入を一度実行した後で，上のセルを再クリックすると，今度は値を持ちます．つまり，セル内容の適用順序は，上からの順にではなく，実行された順（たまたま上からかもしれません）

# %%
a=414

# %%
a=123

# %% [markdown]
# `a=123`の直下にある下のセルですが，セルの実行の順序によっては，他の値に評価されたりします．

# %%
a

# %% [markdown]
# 一続きの操作をセッションと言います．しばらく無操作の状態が続くとセッションは捨てられ記録が残らないことがあります．確実に保存するには，`ファイル>ドライブにコピーを保存`しましょう．Google Driveの，`マイドライブ/Colab Notebooks` フォルダに保存されます．

# %% [markdown]
# セッションをリセットして，変数の値を初期化するには`ランタイム>セッションを再起動する`を選びます．

# %% [markdown]
# 編集をすべて捨てて配布ファイルからやり直したいときは，https://github.com/hig3r/mva/2026 から開き直します．

# %% [markdown]
# 最後に課題です．正規分布に従う確率変数の大きなサンプル（サイズn）で，標本平均値\(m\)と不偏標本分散\(s^2\)の値は次のとおりでした．この時の母平均値の信頼係数$1-a=0.95$の信頼区間は次のようになります．
# $$ m-z\sqrt{S^2/n} < \mu < m+z\sqrt{S^2/n}. $$
# ただし

# %%
n=100
s2=20.0
z=1.96
m=  # 学籍番号の下2桁分

# %% [markdown]
# 信頼区間の下限の値を小数で計算しましょう

# %%
#入力して下限の値を得てね
